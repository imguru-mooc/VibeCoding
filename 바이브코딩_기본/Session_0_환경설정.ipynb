# %% [markdown]
# # 🚀 Claude × Colab AI 어드벤처 워크숍
#
# ## 환경 설정 & 워크숍 소개
#
# ---
#
# | 항목 | 내용 |
# |------|------|
# | **대상** | AI에 관심 있는 누구나 (코딩 초보 환영!) |
# | **시간** | 4시간 (세션당 60분, 휴식 포함) |
# | **준비물** | 노트북, 인터넷, Google 계정, Claude 계정 |
# | **난이도** | ★☆☆☆☆ ~ ★★★☆☆ (점진적 상승) |

# %% [markdown]
# ## 📋 전체 워크숍 구성
#
# | 시간 | 세션 | 주제 |
# |------|------|------|
# | 00:00 ~ 01:00 | 🎬 Session 1 | 영화 추천 AI 만들기 |
# | 01:10 ~ 02:10 | 🖼️ Session 2 | AI 화가 - 이미지 마법사 |
# | 02:20 ~ 03:20 | 💬 Session 3 | AI 감성 분석가 |
# | 03:30 ~ 04:00 | 🧠 Session 4 | AI 예측 마스터 & 종합 정리 |

# %% [markdown]
# ## 🔄 핵심 워크플로우 (이것만 기억하세요!)
#
# ```
# ① Claude에게 코드 요청 (프롬프트 복사 → Claude에 붙여넣기)
#      ↓
# ② 생성된 코드 복사 (코드 블록 우상단 📋 복사 버튼 클릭)
#      ↓
# ③ Colab 빈 셀에 붙여넣기 후 실행 (Shift + Enter)
# ```
#
# > 💡 **코드를 직접 작성할 필요 없습니다!** Claude가 만들어준 코드를 아래 빈 코드 셀에 붙여넣기만 하면 됩니다.

# %% [markdown]
# ---
# ## ✅ Step 0: 환경 테스트
#
# 아래 프롬프트를 복사해서 Claude에게 보내세요.
#
# ---
#
# ### 💬 Claude에게 보낼 프롬프트:
#
# ```
# Google Colab에서 실행 가능한 파이썬 코드를 작성해줘.
# pandas, numpy, matplotlib, sklearn이 정상 작동하는지 확인하는 테스트 코드를 만들어줘.
# 각 라이브러리의 버전을 출력하고, 간단한 테스트(numpy 배열 생성, pandas DataFrame 생성,
# matplotlib 그래프 1개 그리기)를 수행해줘.
# 마지막에 '모든 환경이 준비되었습니다! 🚀' 메시지를 출력해줘.
# ```

# %% [markdown]
# ### ⬇️ Claude가 생성한 코드를 아래 셀에 붙여넣고 실행하세요 (Shift+Enter)

# %% [markdown]
# ---
# ### 🎯 체크포인트
#
# 위 코드 실행 결과를 확인하세요:
# - [ ] pandas 버전이 출력되었나요?
# - [ ] numpy 버전이 출력되었나요?
# - [ ] matplotlib 그래프가 보이나요?
# - [ ] '🚀' 메시지가 출력되었나요?
#
# ✅ 모두 확인되었으면 **Session 1 노트북**으로 이동하세요!
